# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
df=pd.read_csv("Student-Performance.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le=LabelEncoder()
df["Extracurricular Activities"]=le.fit_transform(df["Extracurricular Activities"])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
x=df[["Hours Studied","Previous Scores","Extracurricular Activities","Sleep Hours","Sample Question Papers Practiced"]]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# 9997                                 5
# 9998                                 0
# 9999                                 1
#
# [10000 rows x 5 columns]

# %%
y=df["Performance Index"]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 8349              3               80                           1            9
# 5418              6               43                           0            8
# 867               5               60                           0            8
# 9535              1               79                           0            4
# 1787              3               64                           0            7
# ...             ...              ...                         ...          ...
# 5959              4               92                           0            7
# 2850              1               73                           1            6
# 7152              8               60                           1            6
# 7907              4               47                           1            9
# 1215              5               61                           0            8
#
#       Sample Question Papers Practiced
# 8349                                 1
# 5418                                 9
# 867                                  0
# 9535                                 1
# 1787                                 1
# ...                                ...
# 5959                                 8
# 2850                                 2
# 7152                                 2
# 7907                                 9
# 1215                                 6
#
# [8000 rows x 5 columns]

# %%
scaler=StandardScaler()

x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
x_test
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 4161              8               45                           0            4
# 7492              7               74                           0            7
# 4111              4               67                           0            7
# 4294              5               85                           0            6
# 4246              5               86                           0            9
# ...             ...              ...                         ...          ...
# 4983              6               58                           0            9
# 9917              4               98                           1            9
# 4213              3               62                           0            5
# 8385              1               48                           0            5
# 2148              8               59                           0            9
#
#       Sample Question Papers Practiced
# 4161                                 5
# 7492                                 1
# 4111                                 8
# 4294                                 1
# 4246                                 2
# ...                                ...
# 4983                                 7
# 9917                                 7
# 4213                                 2
# 8385                                 7
# 2148                                 0
#
# [2000 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression

import pickle
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
model=LinearRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test_scaled)

# %%
x_test_scaled
# Out:
# array([[ 1.15058176, -1.42014141, -0.98807114, -1.47810079,  0.14828829],
#        [ 0.7688993 ,  0.25040988, -0.98807114,  0.27216657, -1.24082914],
#        [-0.37614806, -0.15282664, -0.98807114,  0.27216657,  1.19012636],
#        ...,
#        [-0.75783051, -0.44085272, -0.98807114, -0.89467833, -0.89354979],
#        [-1.52119542, -1.24732576, -0.98807114, -0.89467833,  0.842847  ],
#        [ 1.15058176, -0.61366837, -0.98807114,  1.43901148, -1.5881085 ]],
#       shape=(2000, 5))

# %%
model.predict([[ 1.15058176, -1.42014141, -0.98807114, -1.47810079,  0.14828829]])
# Out:
# array([37.16771904])

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 4.216378219177463

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9883912426093424

# %%
import pickle

with open("student_lr_final_model.pkl","wb") as file:
    pickle.dump((model,scaler,le),file)
